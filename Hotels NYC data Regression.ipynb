# %% [markdown]
# # Import libraries

# %%
import numpy as np  
import pandas as pd
import matplotlib as plt
import seaborn as sns
sns.set()

# %%
AB_data = pd.read_csv('AB_NYC_2019.csv')

AB_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
AB_data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Descriptive Statistics
AB_data.describe(include = 'all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
# using head() function to check the first five records
AB_data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [raw]
# # we don't require columns such as
# id, host_id, host_name, last_review,
#
# # we need column such as neighborhood_group, neighbourhood, room_type, price, min nights, number_of_reviews,
# reviews_per_month, calculated_host_listings_count, availability_365

# %%
# Checking the Null values in the dataset
AB_data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
AB_data.shape
# Out:
# (48895, 16)

# %%
# analyzing total counts for differnt categories
AB_data['room_type'].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
# Removing the non required columns from dataset
AB_data.dropna(subset = ['name','host_name'],inplace = True, axis = 0)

AB_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# checking the null values in the dataset
AB_data.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10037
# reviews_per_month                 10037
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
AB_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48858 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48858 non-null  int64
#  1   name                            48858 non-null  object
#  2   host_id                         48858 non-null  int64
#  3   host_name                       48858 non-null  object
#  4   neighbourhood_group             48858 non-null  object
#  5   neighbourhood                   48858 non-null  object
#  6   latitude                        48858 non-null  float64
#  7   longitude                       48858 non-null  float64
#  8   room_type                       48858 non-null  object
#  9   price                           48858 non-null  int64
#  10  minimum_nights                  48858 non-null  int64
#  11  number_of_reviews               48858 non-null  int64
# ...

# %%
# checking the descriptive statistics
AB_data.describe(include = 'all')
# Out:
#                   id            name       host_id host_name  \
# count   4.885800e+04           48858  4.885800e+04     48858
# unique           NaN           47884           NaN     11450
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.902335e+07             NaN  6.763169e+07       NaN
# std     1.098289e+07             NaN  7.862389e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.475980e+06             NaN  7.818669e+06       NaN
# 50%     1.969114e+07             NaN  3.079133e+07       NaN
# 75%     2.915765e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48858         48858  48858.000000  48858.000000
# unique                   5           221           NaN           NaN
# ...

# %%
# Resetting the Indexes of the observations
AB_data = AB_data.reset_index(drop = True)

# %%
AB_data['host_name'].value_counts()
# Out:
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
#                ...
# Panayiota         1
# Emmet             1
# Leidy             1
# Tom & Emma        1
# Caio              1
# Name: host_name, Length: 11450, dtype: int64

# %% [raw]
# data_cleaned = data_4.reset_index(drop=True)

# %%
# we need column such as neighborhood_group, neighbourhood, room_type, price, min nights, number_of_reviews, 
# reviews_per_month, calculated_host_listings_count, availability_365

# %%
# Making the null obseravtions in the reviews to be 0 as no reviews for that hotel booking.

#AB_data.loc[AB_data['reviews_per_month'].isnull() == True]['reviews_per_month']

AB_data.loc[AB_data['reviews_per_month'].isnull() == True,'reviews_per_month'] = 0

# %%
AB_data.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10037
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
data_cleaned1 = AB_data.drop(['id','name','host_name','last_review'], axis = 1)

# %%
data_cleaned1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48858 entries, 0 to 48857
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_id                         48858 non-null  int64
#  1   neighbourhood_group             48858 non-null  object
#  2   neighbourhood                   48858 non-null  object
#  3   latitude                        48858 non-null  float64
#  4   longitude                       48858 non-null  float64
#  5   room_type                       48858 non-null  object
#  6   price                           48858 non-null  int64
#  7   minimum_nights                  48858 non-null  int64
#  8   number_of_reviews               48858 non-null  int64
#  9   reviews_per_month               48858 non-null  float64
#  10  calculated_host_listings_count  48858 non-null  int64
#  11  availability_365                48858 non-null  int64
# ...

# %%
data_cleaned1.describe(include = 'all')
# Out:
#              host_id neighbourhood_group neighbourhood      latitude  \
# count   4.885800e+04               48858         48858  48858.000000
# unique           NaN                   5           221           NaN
# top              NaN           Manhattan  Williamsburg           NaN
# freq             NaN               21643          3917           NaN
# mean    6.763169e+07                 NaN           NaN     40.728941
# std     7.862389e+07                 NaN           NaN      0.054528
# min     2.438000e+03                 NaN           NaN     40.499790
# 25%     7.818669e+06                 NaN           NaN     40.690090
# 50%     3.079133e+07                 NaN           NaN     40.723070
# 75%     1.074344e+08                 NaN           NaN     40.763107
# max     2.743213e+08                 NaN           NaN     40.913060
#
#            longitude        room_type         price  minimum_nights  \
# count   48858.000000            48858  48858.000000    48858.000000
# ...

# %%
# storing numerical variables in hist_data for further exploratory analysis
hist_data = data_cleaned1._get_numeric_data()
hist_data.columns
# Out:
# Index(['host_id', 'latitude', 'longitude', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# Plotting Histograms to observe the data distribution and the skewness
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
for i, col in enumerate(hist_data.columns):
    plt.figure(i)
    sns.histplot(hist_data[col])

# %%
# Plotting barplots to do exploratory analysis of effects of categorical variables
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.barplot('room_type','price',data = data_cleaned1)
plt.show()

sns.barplot('neighbourhood_group','price',data = data_cleaned1)
plt.show()

sns.barplot('neighbourhood_group','price',data = data_cleaned1, hue = 'room_type')
plt.show()
# Out:
# c:\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data_cleaned1['neighbourhood'].value_counts()
# Out:
# Williamsburg          3917
# Bedford-Stuyvesant    3713
# Harlem                2655
# Bushwick              2462
# Upper West Side       1969
#                       ...
# New Dorp                 1
# Woodrow                  1
# Rossville                1
# Willowbrook              1
# Fort Wadsworth           1
# Name: neighbourhood, Length: 221, dtype: int64

# %%
neighbourhood_data = data_cleaned1['neighbourhood'].value_counts().nlargest(15)

# %%
neighbourhood_data.sum()
# Out:
# 28579

# %%
# Understanding the Correlation between all numerical variables
hist_data.corr()
# Out:
#                                  host_id  latitude  longitude     price  \
# host_id                         1.000000  0.020193   0.127198  0.015328
# latitude                        0.020193  1.000000   0.084819  0.033944
# longitude                       0.127198  0.084819   1.000000 -0.149954
# price                           0.015328  0.033944  -0.149954  1.000000
# minimum_nights                 -0.017027  0.025893  -0.062893  0.042804
# number_of_reviews              -0.140273 -0.015198   0.059151 -0.047949
# reviews_per_month               0.209644 -0.018702   0.138759 -0.050586
# calculated_host_listings_count  0.154954  0.019548  -0.114746  0.057460
# availability_365                0.203743 -0.010775   0.082754  0.081817
#
#                                 minimum_nights  number_of_reviews  \
# host_id                              -0.017027          -0.140273
# latitude                              0.025893          -0.015198
# ...

# %%
data_cleaned2 = data_cleaned1.drop(['host_id','latitude','longitude'],axis = 1)

# %%
# using OLS to build the linear regression model
from statsmodels.formula.api import ols

lm_out = ols('price~minimum_nights+number_of_reviews+reviews_per_month+calculated_host_listings_count+availability_365', data= data_cleaned2).fit()

# Checking the model results
lm_out.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     130.9
# Date:                Mon, 16 Aug 2021   Prob (F-statistic):          2.70e-138
# Time:                        00:57:02   Log-Likelihood:            -3.3682e+05
# No. Observations:               48858   AIC:                         6.737e+05
# Df Residuals:                   48852   BIC:                         6.737e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
# As per above model results, all the independet variables are significant as the respective t value are greater than 3. 
# The 95% CI shows us that higher and lower boundaries does not include 0 which is a good indication that we reject the The 
# NULL hypothesis. The R squared and adjusted R squared value is very low i.e. 1.3% which suggest that the model does not 
# suggest the underlying variablity  properly.
